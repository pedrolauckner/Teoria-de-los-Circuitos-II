# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de Circuitos II
#
# # Tarea Semanal 13
#
# #### Por Pedro Lauckner

# %% [markdown]
# Transferencia cargada de un cuadripolo RC
#
# \begin{equation}
# \frac{-I2}{I1} = H * \frac{s^2 + 5s + 4}{s^2 + 8s + 12}
# \end{equation}
#
# \begin{equation}
# Z21 = 6H
# \end{equation}
#
#
# <img src="./Circ.PNG" align="center" width="1000" />
#
#
# Simulaciones en LTSpice:
#
# <img src="./SIM.PNG" align="center" width="1000" />

# %%
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt

# módulo de SciPy
from scipy import signal as sig

from splane import bodePlot, pzmap, pretty_print_bicuad_omegayq


# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)


num = np.array([1, 5, 4]) 
den = np.array([1, 8, 12])

# Transferencia

T_s = sig.TransferFunction(num, den)

# Plot

plt.close('all')
bodePlot(T_s, [-2,2],[5,-15])

# polos y ceros
pzmap(T_s)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %% [markdown]
# Transferencia cargada de un cuadripolo LC
#
# \begin{equation}
# \frac{V2}{I1} = \frac{s^2 + 9}{s^3 + 2s^2 + 2s + 1}
# \end{equation}
#
#
# <img src="./Circ2.PNG" align="center" width="1000" />
#
#
# Simulaciones en LTSpice:
#
# <img src="./SIM2.PNG" align="center" width="1000" />

# %%
num = np.array([1/9, 0, 1]) 
den = np.array([1, 2, 2, 1])

# Transferencia

T_s = sig.TransferFunction(num, den)

# Plot

plt.close('all')
bodePlot(T_s, [-3,3],[10,-60])

# polos y ceros
pzmap(T_s)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)
