# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de Circuitos II
#
# # Tarea Semanal 15
#
# #### Por Pedro Lauckner

# %% [markdown]
# Filtro pasabajos chebyshev de orden 4 con 1 dB de ripple
# Cuadripolo no disipativo cargado a la salida y a la entrada
#
#
# \begin{equation}
# T(s) = \frac{1}{4.0714(S^2 + 0.9865)(S^2 + 0.2794)}
# \end{equation}
#
#
# \begin{equation}
# Z1 = \frac{2.1s^4 + s^3 + 2.575s^2 + 0.779s + 0.42}{s^3 + 0.476s^2 + 0.779s + 0.158}
# \end{equation}
#
#
# \begin{equation}
# S11 = \frac{s^4 + s^2 + 0.125}{s^4 + 0.953*s^3 + 1.454s^2 + 0.743s + 0.276}
# \end{equation}
#
#
# <img src="./Circ.PNG" align="center" width="1000" />
#
#
# Simulaciones en LTSpice:
#
# S11:
# <img src="./SIM_S11.PNG" align="center" width="1000" />
#
#
# S21:
# <img src="./SIM_S21.PNG" align="center" width="1000" />
#
#
# T(s)
# <img src="./SIM_Ts.PNG" align="center" width="1000" />

# %%
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt

# módulo de SciPy
from scipy import signal as sig

from splane import bodePlot, pzmap, pretty_print_bicuad_omegayq


# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

# S11

num = np.array([1, 0, 1, 0, 0.125]) 
den = np.array([1, 0.953, 1.454, 0.743, 0.276])

# Transferencia

T_s = sig.TransferFunction(num, den)

# Plot

plt.close('all')
bodePlot(T_s, [-2,1],[5,-60])

# polos y ceros
pzmap(T_s)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %%
# T(s)

num = np.array([1]) 
den = np.array([4.0714, 3.88, 5.92, 3.023, 1.122])

# Transferencia

T_s = sig.TransferFunction(num, den)

# Plot

plt.close('all')
bodePlot(T_s, [-1,1],[5,-60])

# polos y ceros
pzmap(T_s)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)
