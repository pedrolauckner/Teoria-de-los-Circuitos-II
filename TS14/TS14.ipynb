# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de Circuitos II
#
# # Tarea Semanal 14
#
# #### Por Pedro Lauckner

# %% [markdown]
# \begin{equation}
# S11 = \frac{Z1 - Rg1}{Z1 + Rg1}
# \end{equation}
#
# Rg1 = 1
#
# \begin{equation}
# Z1 = \frac{2s^3 + 2s^2 + 2s + 1}{2s^2 + 2s + 1}
# \end{equation}
#
#
# \begin{equation}
# S11 = S22 = \frac{s^3}{s^3 + 2s^2 + 2s + 1}
# \end{equation}
#
# \begin{equation}
# S12 = S21 = \frac{1}{s^3 + 2s^2 + 2s + 1}
# \end{equation}
#
#
# <img src="./Circ.PNG" align="center" width="1000" />
#
#
# Simulaciones en LTSpice:
#
# S11 = S22:
# <img src="./SIM_S11.PNG" align="center" width="1000" />
#
#
# S12 = S21:
# <img src="./SIM_S21.PNG" align="center" width="1000" />
#
#
# Z1:
# <img src="./SIM_Z1.PNG" align="center" width="1000" />

# %%
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt

# módulo de SciPy
from scipy import signal as sig

from splane import bodePlot, pzmap, pretty_print_bicuad_omegayq


# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

# S11 = S22 =

num = np.array([1, 0, 0, 0]) 
den = np.array([1, 2, 2, 1])

# Transferencia

T_s = sig.TransferFunction(num, den)

# Plot

plt.close('all')
bodePlot(T_s, [-2,2],[5,-100])

# polos y ceros
pzmap(T_s)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %%
# S12 = S21 =

num = np.array([1]) 
den = np.array([1, 2, 2, 1])

# Transferencia

T_s = sig.TransferFunction(num, den)

# Plot

plt.close('all')
bodePlot(T_s, [-2,2],[5,-100])

# polos y ceros
pzmap(T_s)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %%
# Z1

num = np.array([2, 2, 2, 1]) 
den = np.array([2, 2, 1])

# Transferencia

T_s = sig.TransferFunction(num, den)

# Plot

plt.close('all')
bodePlot(T_s, [-2,2],[40,-10])

# polos y ceros
pzmap(T_s)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)
