# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de Circuitos II
#
# # Tarea Semanal 6
#
# #### Por Pedro Lauckner

# %% [markdown]
# Se busca implimentar un filtro notch pasa altos en cascada con un filtro pasa altos de primer orden
#
# <img src="./Circ.PNG" align="center" width="1000" />
#
# \begin{equation}
# T(s) = \frac{V2}{V1} = \frac{s^2 + Wz^2}{s^2 + s \frac{1}{Qp} + 1} * \frac{s}{s + 1}
# \end{equation}
#
# \begin{equation}
# Qp = 1
# \end{equation}
#
# \begin{equation}
# Wz = \frac{1}{3}
# \end{equation}
#
# \begin{equation}
# T(s) = \frac{s^2 + 1/9}{s^2 + s + 1} * \frac{s}{s + 1}
# \end{equation}
#
#
# Transferencia del circuito propuesto con un GIC
#
# \begin{equation}
# T(s) = \frac{s^2 + \frac{R1-R2}{C^2*R*R1*R2}}{s^2 + s \frac{1}{C*R1} +  \frac{1}{C^2*R*R2}}
# \end{equation}
#
# Transferencia del circuito CR
#
# T(s) = \frac{s}{s + \frac{1}{C2 R3} }
#
# \begin{equation}
# R1 = C = C2 = R3 = 1
# \end{equation}
#
# \begin{equation}
# R2 =  \frac{8}{9} = 0.888
# \end{equation}
#
# \begin{equation}
# R =  \frac{9}{8} = 1.125
# \end{equation}
#
#
# Desnormalizo por Wp
#
# \begin{equation}
# C = \frac{C ant}{2*pi*300} = 530 uF
# \end{equation}

# %%
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt

# módulo de SciPy
from scipy import signal as sig

from splane import bodePlot, pzmap, pretty_print_bicuad_omegayq


# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)


# Numerador y denominador 
# Antes de desnormalizar

num = np.array([1, 0 , 1/9 , 0]) 
den = np.array([1, 2, 2, 1])

# Transferencia

T_s = sig.TransferFunction(num, den)

# Plot

plt.close('all')
bodePlot(T_s, [-3,4],[10,-80])

# polos y ceros
pzmap(T_s)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %% [markdown]
# Simulacion circuital en LTSpice
#
# <img src="./SIM.PNG" align="center" width="1000" />
