# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de Circuitos II
#
# # Tarea Semanal 2
#
# #### Por Pedro Lauckner

# %% [markdown]
# Se plantea el siguiente circuito llamado Akerberg Mosberg y se obtiene su transferencia
#
# <img src="./Circuito.PNG" align="center" width="900" />
#
# \begin{equation}
# TL(s) = \frac{V2}{V1} = \frac{-H * Wo^2}{s^2 + s\frac{Wo}{Q} + Wo^2}.
# \end{equation}
#
# Con
# \begin{equation}
# H = \frac{R3}{R1} = 10
# \end{equation}
#
# \begin{equation}
# Wo = \frac{1}{C R3} = 1
# \end{equation}
#
# \begin{equation}
# Q = \frac{R2}{R3} = 3
# \end{equation}
#
# \begin{equation}
# C = 100uf
# \end{equation}
#
# \begin{equation}
# R1 = 1k
# \end{equation}
#
# \begin{equation}
# R2 = 10k
# \end{equation}
#
# \begin{equation}
# R3 = 30k
# \end{equation}
#
#
# \begin{equation}
# TL(s) = \frac{-10 * 1}{s^2 + s\frac{1}{3} + 1}.
# \end{equation}
#
#
# Si quiero un pasabanda cambio donde tomo la salida y queda la siguiente transferencia
#
# \begin{equation}
# TB(s) = \frac{V2}{V1} = \frac{-H * s * Wo^2}{s^2 + s\frac{Wo}{Q} + Wo^2}.
# \end{equation}
#
# con los mismos valores de componentes que antes queda
#
# \begin{equation}
# TL(s) = \frac{-s* 10 * 1}{s^2 + s\frac{1}{3} + 1}.
# \end{equation}

# %%
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

fig_font_family = 'Arial'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})

# módulo de SciPy
from scipy import signal as sig


# un módulo adaptado a mis necesidades
from splane import analyze_sys, pretty_print_bicuad_omegayq, pretty_print_lti
        
all_sos = []
all_values = [1]

for ii in all_values:
    
    A = ii
    Wo = 1
    Wc = 1
    H=10
    Q=3
    
    num = np.array([ (-H*Wo*Wo) ]) 
    den = np.array([ 1, (Wo/Q), Wo*Wo])
    
    #pretty_print_bicuad_omegayq(num,den)

    mi_sos = sig.TransferFunction(num,den)
    
    pretty_print_lti(mi_sos) 

    all_sos += [mi_sos]
    
plt.close('all')
analyze_sys(all_sos, sys_name=all_values)
# Out:
# $\displaystyle \frac{-10 }{s^2 + s \,\, 0.3333 +   1 }$

# %% [markdown]
# A continuacion se adjuntan simulaciones circuitales en LTSpice para verificar lo anterior
#
# <img src="./SIM_Low.PNG" align="center" width="1000" />

# %%
Ahora veamos las simulaciones si tomamos la salida pasa banda

# %%
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

fig_font_family = 'Arial'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})

# módulo de SciPy
from scipy import signal as sig


# un módulo adaptado a mis necesidades
from splane import analyze_sys, pretty_print_bicuad_omegayq, pretty_print_lti
        
all_sos = []
all_values = [1]

for ii in all_values:
    
    A = ii
    Wo = 1
    Wc = 1
    H=10
    Q=3
    
    num = np.array([ 10, 0 ]) # no se puede poner el menos, escribe mal la formula
    den = np.array([ 1, (Wo/Q), Wo*Wo])
    
    #pretty_print_bicuad_omegayq(num,den)

    mi_sos = sig.TransferFunction(num,den)
    
    pretty_print_lti(mi_sos) 

    all_sos += [mi_sos]
    
plt.close('all')
analyze_sys(all_sos, sys_name=all_values)
# Out:
# $\displaystyle \frac{s \,\,  10 }{s^2 + s \,\, 0.3333 +   1 }$

# %% [markdown]
# A continuacion se adjuntan simulaciones circuitales en LTSpice para verificar lo anterior
#
# <img src="./SIM_Band.PNG" align="center" width="1000" />
