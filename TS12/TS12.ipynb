# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de Circuitos II
#
# # Tarea Semanal 12
#
# #### Por Pedro Lauckner

# %% [markdown]
# Se plantea un cuadripolo con los siguientes parametros:
#
# \begin{equation}
# Y11(s) = \frac{I1}{V1} (V2=0)  = \frac{3*s^3 + 7*s}{(s^2 + 2)(s^2 + 5)}
# \end{equation}
#
# \begin{equation}
# Y21(s) = \frac{I2}{V1} (V2=0)  = \frac{s^3 + s}{(s^2 + 2)(s^2 + 5)}
# \end{equation}
#
#
# <img src="./Circ.PNG" align="center" width="1000" />
#
#
# Simulaciones de Y11 e Y21 en LTSpice:
#
# <img src="./SIM_Y11.PNG" align="center" width="1000" />
#
# <img src="./SIM_Y21.PNG" align="center" width="1000" />

# %%
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt

# módulo de SciPy
from scipy import signal as sig

from splane import bodePlot, pzmap, pretty_print_bicuad_omegayq


# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)


# Numerador y denominador Y11

num = np.array([3, 0, 7, 0]) 
den = np.array([1, 0, 7, 0, 10])

# Transferencia

T_s = sig.TransferFunction(num, den)

# Plot

plt.close('all')
bodePlot(T_s, [-1,1],[50,-40])

# polos y ceros
pzmap(T_s)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %%
#########################################################
# Numerador y denominador Y21

num = np.array([1, 0, 1, 0]) 
den = np.array([1, 0, 7, 0, 10])

# Transferencia

T_s = sig.TransferFunction(num, den)

# Plot

plt.close('all')
bodePlot(T_s, [-2,2],[50,-60])

# polos y ceros
pzmap(T_s)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %% [markdown]
# Dada la siguiente transferencia obtener topologia circuital
#
# \begin{equation}
# Ts(s) = \frac{V2}{V1} = \frac{k*(s + 1)}{(s + 2)(s + 4)}
# \end{equation}
#
# \begin{equation}
# Y22(s) = \frac{(s + 2)(s + 4)}{(s + 3)}
# \end{equation}
#
#
# <img src="./Circ2.PNG" align="center" width="1000" />
#
#
# Simulaciones de T(s) en LTSpice:
#
# <img src="./SIM.PNG" align="center" width="1000" />

# %%
#########################################################
# Numerador y denominador Y21

num = np.array([1.25, 1.25]) 
den = np.array([1, 6, 8])

# Transferencia

T_s = sig.TransferFunction(num, den)

# Plot

plt.close('all')
bodePlot(T_s, [-3,3],[0,-60])

# polos y ceros
pzmap(T_s)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)
