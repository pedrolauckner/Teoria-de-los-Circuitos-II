# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de Circuitos II
#
# # Tarea Semanal 4
#
# #### Por Pedro Lauckner

# %% [markdown]
# Se plantea un filtro pasa banda chebyshev de orden 6 a partir de un pasabajos chebyshev de orden 3 mediante transformacion
#
# <img src="./CircPas.PNG" align="center" width="1000" />
#
# \begin{equation}
# T(s) = \frac{V2}{V1} = K * \frac{s\frac{W1}{Q1}}{s^2 + s\frac{W1}{Q1} + W1^2} * \frac{s\frac{W2}{Q2}}{s^2 + s\frac{W2}{Q2} + W2^2} * \frac{s\frac{W3}{Q3}}{s^2 + s\frac{W3}{Q3} + W3^2}
# \end{equation}
#
# Con
# \begin{equation}
# W1^2 = \frac{1}{L1 C} = 1.2266
# \end{equation}
#
# \begin{equation}
# \frac{W1}{Q1} = \frac{1}{R1 C} = 0.069
# \end{equation}
#
# \begin{equation}
# W2^2 = \frac{1}{L2 C} = 1
# \end{equation}
#
# \begin{equation}
# \frac{W2}{Q2} = \frac{1}{R2 C} = 0.1252
# \end{equation}
#
# \begin{equation}
# W3^2 = \frac{1}{L3 C} = 0.8152
# \end{equation}
#
# \begin{equation}
# \frac{W3}{Q3} = \frac{1}{R3 C} = 0.0562
# \end{equation}
#
# \begin{equation}
# K = 11.8
# \end{equation}
#
# \begin{equation}
# C = 1
# \end{equation}
#
# \begin{equation}
# L1 = 0.81526
# \end{equation}
#
# \begin{equation}
# R1 = 14.4927
# \end{equation}
#
# \begin{equation}
# L2 = 1
# \end{equation}
#
# \begin{equation}
# R2 = 7.9872
# \end{equation}
#
# \begin{equation}
# L3 = 1.2267
# \end{equation}
#
# \begin{equation}
# R3 = 17.7936
# \end{equation}
#
# \begin{equation}
# T(s) = 11.8 * \frac{s*0.069}{s^2 + s0.069 + 1.2266} * \frac{s*0.1252}{s^2 + s*0.1252 + 1} * \frac{s*0.0562}{s^2 + s*0.0562 + 0.8152}
# \end{equation}
#
#
# Si juntamos todo en una transferencia de orden 6 queda:
#
# \begin{equation}
# T(s) = \frac{s^3 5.73 10^{-3}}{s^6 + s^5 0.2504 +s^4 3.0614 + s^3 0.5065 + s^2 3.0613 + s 0.2504 + 1}
# \end{equation}
#
#
# Desnormalizo por Wo
#
# \begin{equation}
# Wo = 2*pi*22000
# \end{equation}
#
# Las resistencias se mantiene igual mientras que los nuevos valores de los capacitores e inductores son:
#
#
# \begin{equation}
# C = 1/Wo = 7.234 uF
# \end{equation}
#
# \begin{equation}
# L1 = 0.81526/Wo = 5.8978 uHy
# \end{equation}
#
# \begin{equation}
# L2 = 1/Wo = 7.234 uHy
# \end{equation}
#
# \begin{equation}
# L3 = 1.2267/Wo = 8.874 uHy
# \end{equation}

# %% [markdown]
# Su version activa sin inductores que responde a la misma transferencia
#
# <img src="./CircAct.PNG" align="center" width="1000" />

# %%
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt

# módulo de SciPy
from scipy import signal as sig

from splane import bodePlot, pzmap, pretty_print_bicuad_omegayq


# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)


# Numerador y denominador 
# Antes de desnormalizar

num = np.array([1, 0, 0 ]) 
den = np.array([1, 0.2504, 3.0614, 0.5065, 3.0613, 0.2504, 1])

# Transferencia

T_s = sig.TransferFunction(num, den)

# Plot

plt.close('all')
bodePlot(T_s, [-1,1],[60,-60])

# polos y ceros
pzmap(T_s)
# Out:
# (2, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %% [markdown]
# Simulacion circuital en LTSpice del circuito de redes pasivas
#
# <img src="./SIM_PAS.PNG" align="center" width="1000" />
#
#
# Simulacion circuital en LTSpice del circuito de inductores activados
#
# <img src="./SIM_ACT.PNG" align="center" width="1000" />
